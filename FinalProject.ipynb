# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# /bin/sh: conda: command not found
# /bin/sh: conda: command not found
# Folium installed
# Libraries imported.

# %%
conda update -n base -c defaults conda
# Out:
# ...
# Solving environment: done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install geopy --user
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install folium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
CLIENT_ID = 'TMYHYXPHGWNNH2EBB5CVB1YAJJY3YZBNPQOB4IQ4QCRPZ2CM' # your Foursquare ID
CLIENT_SECRET = 'QDB3LV3XJ0ZBRC1HNTMP3LVMN1ZY0FSZKLYGJH2TTYGG5TRB' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: TMYHYXPHGWNNH2EBB5CVB1YAJJY3YZBNPQOB4IQ4QCRPZ2CM
# CLIENT_SECRET:QDB3LV3XJ0ZBRC1HNTMP3LVMN1ZY0FSZKLYGJH2TTYGG5TRB

# %%
address = 'Tobrucká 4, 811 02 Bratislava'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 48.1413326 17.1135238

# %%
https://api.foursquare.com/v2/venues/search?client_id=TMYHYXPHGWNNH2EBB5CVB1YAJJY3YZBNPQOB4IQ4QCRPZ2CM&client_secret=QDB3LV3XJ0ZBRC1HNTMP3LVMN1ZY0FSZKLYGJH2TTYGG5TRB&v=20191229&ll=48.1413326,17.1135238&query=Gym/FitnessCenter&radius=1000&limit=30
# Out:
#   File "<ipython-input-7-6ce25e0b724b>", line 1
#     https://api.foursquare.com/v2/venues/search?client_id=TMYHYXPHGWNNH2EBB5CVB1YAJJY3YZBNPQOB4IQ4QCRPZ2CM&client_secret=QDB3LV3XJ0ZBRC1HNTMP3LVMN1ZY0FSZKLYGJH2TTYGG5TRB&v=20191229&ll=48.1413326,17.1135238&query=Gym/FitnessCenter&radius=1000&limit=30
#            ^
# SyntaxError: invalid syntax

# %%
search_query = 'Gym / Fitness Center'
radius = 1000
print(search_query + ' .... OK!')
# Out:
# Gym / Fitness Center .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id=TMYHYXPHGWNNH2EBB5CVB1YAJJY3YZBNPQOB4IQ4QCRPZ2CM&client_secret=QDB3LV3XJ0ZBRC1HNTMP3LVMN1ZY0FSZKLYGJH2TTYGG5TRB&v=20191229&ll=48.1413326,17.1135238&query=Gym/FitnessCenter&radius=1000&limit=30'
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=TMYHYXPHGWNNH2EBB5CVB1YAJJY3YZBNPQOB4IQ4QCRPZ2CM&client_secret=QDB3LV3XJ0ZBRC1HNTMP3LVMN1ZY0FSZKLYGJH2TTYGG5TRB&v=20191229&ll=48.1413326,17.1135238&query=Gym/FitnessCenter&radius=1000&limit=30'

# %%
import requests

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5e08f3ac3907e7001b4a3d68'},
#  'response': {'venues': [{'id': '51d12263498ec2e471824912',
#     'name': "Marrol's Hotel Gym",
#     'location': {'address': 'Tobrucká 4',
#      'lat': 48.141297603139854,
#      'lng': 17.113362550735474,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.141297603139854,
#        'lng': 17.113362550735474}],
#      'distance': 12,
#      'postalCode': '811 02',
#      'cc': 'SK',
#      'city': 'Bratislava',
#      'state': 'Bratislavský kraj',
#      'country': 'Slovensko',
#      'formattedAddress': ['Tobrucká 4', '811 02 Bratislava', 'Slovensko']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1577645031',
#     'hasPerk': False},
# ...

# %%
from pandas.io.json import json_normalize

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# transform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                          id                   name  \
# 0  51d12263498ec2e471824912     Marrol's Hotel Gym
# 1  4b9e1102f964a520e2c836e3                FanatiX
# 2  5781ffc6498e1df4c58799de  Tulip House Hotel Gym
# 3  57820029cd10c6e07f40dea9  Tulip House Hotel Gym
# 4  4cb9937af50e224b543deefb              Freya Gym
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...  v-1577645031    False
# 1  [{'id': '4bf58dd8d48988d175941735', 'name': 'G...  v-1577645031    False
# 2  [{'id': '4bf58dd8d48988d175941735', 'name': 'G...  v-1577645031    False
# 3  [{'id': '4bf58dd8d48988d175941735', 'name': 'G...  v-1577645031    False
# 4  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...  v-1577645031    False
#
#   location.address  location.lat  location.lng  \
# 0       Tobrucká 4     48.141298     17.113363
# 1      Dunajská 23     48.146094     17.118888
# 2              NaN     48.142445     17.114177
# ...

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                               name            categories         address  \
# 0               Marrol's Hotel Gym                   Gym      Tobrucká 4
# 1                          FanatiX  Gym / Fitness Center     Dunajská 23
# 2            Tulip House Hotel Gym  Gym / Fitness Center             NaN
# 3            Tulip House Hotel Gym  Gym / Fitness Center             NaN
# 4                        Freya Gym                   Gym  Rybne namestie
# 5  Austria Trend Hotel Gym & Sauna  Gym / Fitness Center             NaN
# 6                Austria Trend Gym                   Gym             NaN
# 7             Jonshon Controls Gym  Gym / Fitness Center    Privinoba 19
#
#          lat        lng                                     labeledLatLngs  \
# 0  48.141298  17.113363  [{'label': 'display', 'lat': 48.14129760313985...
# 1  48.146094  17.118888  [{'label': 'display', 'lat': 48.14609446278672...
# 2  48.142445  17.114177  [{'label': 'display', 'lat': 48.142445, 'lng':...
# ...

# %%
dataframe_filtered.name
# Out:
# 0                 Marrol's Hotel Gym
# 1                            FanatiX
# 2              Tulip House Hotel Gym
# 3              Tulip House Hotel Gym
# 4                          Freya Gym
# 5    Austria Trend Hotel Gym & Sauna
# 6                  Austria Trend Gym
# 7               Jonshon Controls Gym
# Name: name, dtype: object

# %%
import folium
from folium.plugins import FastMarkerCluster

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13)

# add a red circle marker to represent the Marrols Boutique Hotel
folium.features.Marker(
    [48.1413326,17.1135238],
    radius=10,
    color='red',
    popup='Marrols Boutique Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# %%
# add fitness centers as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.Marker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
